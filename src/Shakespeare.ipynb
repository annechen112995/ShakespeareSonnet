# %%
import os
import numpy as np
import hmmlearn as hmm
import keras

from shakespeare_processing import process_data
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Westwood/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def load_data(filename, skiprows = 1):
    
    text = open(os.path.join(os.getcwd(), filename)).read()
    new_text = text.strip().split('\n')
    
    return new_text

# %%
text = load_data("data/shakespeare.txt")

# %%
processed_data = process_data(text)
# Out:
# [('thy', 287), ('thou', 235), ('thee', 162), ('love', 162), ('doth', 88), ('self', 77), ('mine', 63), ('shall', 59), ('eyes', 56), ('sweet', 55), ('time', 53), ('beauty', 52), ('art', 51), ('yet', 51), ('heart', 50), ('thine', 44), ('fair', 43), ('make', 43), ('one', 43), ('hath', 43), ('still', 41), ('eye', 37), ('true', 37), ('see', 35), ('like', 34), ('loves', 34), ('though', 33), ('dost', 29), ('live', 29), ('upon', 29), ('every', 29), ('may', 29), ('say', 28), ('praise', 28), ('world', 27), ('give', 27), ('might', 26), ('let', 26), ('times', 25), ('day', 25), ('since', 24), ('even', 24), ('ill', 24), ('show', 23), ('life', 23), ('well', 23), ('best', 23), ('truth', 23), ('old', 22), ('new', 22), ('look', 22), ('night', 22), ('thus', 22), ('must', 21), ('would', 21), ('dear', 21), ('part', 20), ('worth', 19), ('made', 19), ('face', 19), ('whose', 19), ('nothing', 19), ('alone', 19), ('better', 19), ('beautys', 18), ('days', 18), ('hand', 18), ('thought', 18), ('away', 18), ('false', 18), ('thoughts', 18), ('much', 17), ('sight', 17), ('hast', 17), ('know', 17), ('therefore', 17), ('name', 17), ('mind', 16), ('hate', 16), ('find', 16), ('muse', 16), ('far', 16), ('dead', 16), ('never', 15), ('tell', 15), ('age', 15), ('death', 15), ('youth', 15), ('others', 15), ('good', 15), ('men', 15), ('verse', 15), ('come', 15), ('poor', 15), ('think', 15), ('gentle', 14), ('wilt', 14), ('state', 14), ('till', 14), ('things', 14)]

# %%
processed_data
# Out:
# ['1',
#  'fairest',
#  'creatures',
#  'desire',
#  'increase',
#  'thereby',
#  'beautys',
#  'rose',
#  'might',
#  'never',
#  'die',
#  'riper',
#  'time',
#  'decease',
#  'tender',
#  'heir',
#  'might',
#  'bear',
#  'memory',
#  'thou',
#  'contracted',
#  'thine',
#  'bright',
#  'eyes',
#  'feedst',
#  'thy',
#  'lights',
#  'flame',
#  'selfsubstantial',
#  'fuel',
#  'making',
#  'famine',
#  'abundance',
#  'lies',
#  'thy',
#  'self',
#  'thy',
#  'foe',
#  'thy',
#  'sweet',
#  'self',
#  'cruel',
#  'thou',
#  'art',
#  'worlds',
#  'fresh',
#  'ornament',
#  'herald',
#  'gaudy',
#  'spring',
#  'within',
#  'thine',
#  'bud',
#  'buriest',
#  'thy',
#  'content',
#  'tender',
#  'churl',
#  'makst',
#  'waste',
#  'niggarding',
#  'pity',
#  'world',
#  'else',
#  'glutton',
#  'eat',
#  'worlds',
#  'due',
#  'grave',
#  'thee',
#  '2',
#  'forty',
#  'winters',
#  'shall',
#  'besiege',
#  'thy',
#  'brow',
#  'dig',
#  'deep',
#  'trenches',
#  'thy',
#  'beautys',
#  'field',
#  'thy',
#  'youths',
#  'proud',
#  'livery',
#  'gazed',
#  'tattered',
#  'weed',
#  'small',
#  'worth',
#  'held',
#  'asked',
#  'thy',
#  'beauty',
#  'lies',
#  'treasure',
#  'thy',
#  'lusty',
#  'days',
#  'say',
#  'within',
#  'thine',
#  'deep',
#  'sunken',
#  'eyes',
#  'alleating',
#  'shame',
#  'thriftless',
#  'praise',
#  'much',
#  'praise',
#  'deserved',
#  'thy',
#  'beautys',
#  'use',
#  'thou',
#  'couldst',
#  'answer',
#  'fair',
#  'child',
#  'mine',
#  'shall',
#  'sum',
#  'count',
#  'make',
#  'old',
#  'excuse',
#  'proving',
#  'beauty',
#  'succession',
#  'thine',
#  'new',
#  'made',
#  'thou',
#  'art',
#  'old',
#  'see',
#  'thy',
#  'blood',
#  'warm',
#  'thou',
#  'feelst',
#  'cold',
#  '3',
#  'look',
#  'thy',
#  'glass',
#  'tell',
#  'face',
#  'thou',
#  'viewest',
#  'time',
#  'face',
#  'form',
#  'another',
#  'whose',
#  'fresh',
#  'repair',
#  'thou',
#  'renewest',
#  'thou',
#  'dost',
#  'beguile',
#  'world',
#  'unbless',
#  'mother',
#  'fair',
#  'whose',
#  'uneared',
#  'womb',
#  'disdains',
#  'tillage',
#  'thy',
#  'husbandry',
#  'fond',
#  'tomb',
#  'selflove',
#  'stop',
#  'posterity',
#  'thou',
#  'art',
#  'thy',
#  'mothers',
#  'glass',
#  'thee',
#  'calls',
#  'back',
#  'lovely',
#  'april',
#  'prime',
#  'thou',
#  'windows',
#  'thine',
#  'age',
#  'shalt',
#  'see',
#  'despite',
#  'wrinkles',
#  'thy',
#  'golden',
#  'time',
#  'thou',
#  'live',
#  'remembered',
#  'die',
#  'single',
#  'thine',
#  'image',
#  'dies',
#  'thee',
#  '4',
#  'unthrifty',
#  'loveliness',
#  'dost',
#  'thou',
#  'spend',
#  'upon',
#  'thy',
#  'self',
#  'thy',
#  'beautys',
#  'legacy',
#  'natures',
#  'bequest',
#  'gives',
#  'nothing',
#  'doth',
#  'lend',
#  'frank',
#  'lends',
#  'free',
#  'beauteous',
#  'niggard',
#  'dost',
#  'thou',
#  'abuse',
#  'bounteous',
#  'largess',
#  'given',
#  'thee',
#  'give',
#  'profitless',
#  'usurer',
#  'dost',
#  'thou',
#  'use',
#  'great',
#  'sum',
#  'sums',
#  'yet',
#  'canst',
#  'live',
#  'traffic',
#  'thy',
#  'self',
#  'alone',
#  'thou',
#  'thy',
#  'self',
#  'thy',
#  'sweet',
#  'self',
#  'dost',
#  'deceive',
#  'nature',
#  'calls',
#  'thee',
#  'gone',
#  'acceptable',
#  'audit',
#  'canst',
#  'thou',
#  'leave',
#  'thy',
#  'unused',
#  'beauty',
#  'must',
#  'tombed',
#  'thee',
#  'used',
#  'lives',
#  'th',
#  'executor',
#  '5',
#  'hours',
#  'gentle',
#  'work',
#  'frame',
#  'lovely',
#  'gaze',
#  'every',
#  'eye',
#  'doth',
#  'dwell',
#  'play',
#  'tyrants',
#  'unfair',
#  'fairly',
#  'doth',
#  'excel',
#  'neverresting',
#  'time',
#  'leads',
#  'summer',
#  'hideous',
#  'winter',
#  'confounds',
#  'sap',
#  'checked',
#  'frost',
#  'lusty',
#  'leaves',
#  'quite',
#  'gone',
#  'beauty',
#  'oersnowed',
#  'bareness',
#  'every',
#  'summers',
#  'distillation',
#  'left',
#  'liquid',
#  'prisoner',
#  'pent',
#  'walls',
#  'glass',
#  'beautys',
#  'effect',
#  'beauty',
#  'bereft',
#  'remembrance',
#  'flowers',
#  'distilled',
#  'though',
#  'winter',
#  'meet',
#  'leese',
#  'show',
#  'substance',
#  'still',
#  'lives',
#  'sweet',
#  '6',
#  'let',
#  'winters',
#  'ragged',
#  'hand',
#  'deface',
#  'thee',
#  'thy',
#  'summer',
#  'ere',
#  'thou',
#  'distilled',
#  'make',
#  'sweet',
#  'vial',
#  'treasure',
#  'thou',
#  'place',
#  'beautys',
#  'treasure',
#  'ere',
#  'selfkilled',
#  'use',
#  'forbidden',
#  'usury',
#  'happies',
#  'pay',
#  'willing',
#  'loan',
#  'thats',
#  'thy',
#  'self',
#  'breed',
#  'another',
#  'thee',
#  'ten',
#  'times',
#  'happier',
#  'ten',
#  'one',
#  'ten',
#  'times',
#  'thy',
#  'self',
#  'happier',
#  'thou',
#  'art',
#  'ten',
#  'thine',
#  'ten',
#  'times',
#  'refigured',
#  'thee',
#  'could',
#  'death',
#  'thou',
#  'shouldst',
#  'depart',
#  'leaving',
#  'thee',
#  'living',
#  'posterity',
#  'selfwilled',
#  'thou',
#  'art',
#  'much',
#  'fair',
#  'deaths',
#  'conquest',
#  'make',
#  'worms',
#  'thine',
#  'heir',
#  '7',
#  'lo',
#  'orient',
#  'gracious',
#  'light',
#  'lifts',
#  'burning',
#  'head',
#  'eye',
#  'doth',
#  'homage',
#  'newappearing',
#  'sight',
#  'serving',
#  'looks',
#  'sacred',
#  'majesty',
#  'climbed',
#  'steepup',
#  'heavenly',
#  'hill',
#  'resembling',
#  'strong',
#  'youth',
#  'middle',
#  'age',
#  'yet',
#  'mortal',
#  'looks',
#  'adore',
#  'beauty',
#  'still',
#  'attending',
#  'golden',
#  'pilgrimage',
#  'highmost',
#  'pitch',
#  'weary',
#  'car',
#  'like',
#  'feeble',
#  'age',
#  'reeleth',
#  'day',
#  'eyes',
#  'fore',
#  'duteous',
#  'converted',
#  'low',
#  'tract',
#  'look',
#  'another',
#  'way',
#  'thou',
#  'thy',
#  'self',
#  'outgoing',
#  'thy',
#  'noon',
#  'unlooked',
#  'diest',
#  'unless',
#  'thou',
#  'get',
#  'son',
#  '8',
#  'music',
#  'hear',
#  'hearst',
#  'thou',
#  'music',
#  'sadly',
#  'sweets',
#  'sweets',
#  'war',
#  'joy',
#  'delights',
#  'joy',
#  'lovst',
#  'thou',
#  'thou',
#  'receivst',
#  'gladly',
#  'else',
#  'receivst',
#  'pleasure',
#  'thine',
#  'annoy',
#  'true',
#  'concord',
#  'welltuned',
#  'sounds',
#  'unions',
#  'married',
#  'offend',
#  'thine',
#  'ear',
#  'sweetly',
#  'chide',
#  'thee',
#  'confounds',
#  'singleness',
#  'parts',
#  'thou',
#  'shouldst',
#  'bear',
#  'mark',
#  'one',
#  'string',
#  'sweet',
#  'husband',
#  'another',
#  'strikes',
#  'mutual',
#  'ordering',
#  'resembling',
#  'sire',
#  'child',
#  'happy',
#  'mother',
#  'one',
#  'one',
#  'pleasing',
#  'note',
#  'sing',
#  'whose',
#  'speechless',
#  'song',
#  'many',
#  'seeming',
#  'one',
#  'sings',
#  'thee',
#  'thou',
#  'single',
#  'wilt',
#  'prove',
#  'none',
#  '9',
#  'fear',
#  'wet',
#  'widows',
#  'eye',
#  'thou',
#  'consumst',
#  'thy',
#  'self',
#  'single',
#  'life',
#  'ah',
#  'thou',
#  'issueless',
#  'shalt',
#  'hap',
#  'die',
#  'world',
#  'wail',
#  'thee',
#  'like',
#  'makeless',
#  'wife',
#  'world',
#  'thy',
#  'widow',
#  'still',
#  'weep',
#  'thou',
#  'form',
#  'thee',
#  'hast',
#  'left',
#  'behind',
#  'every',
#  'private',
#  'widow',
#  'well',
#  'may',
#  'keep',
#  'childrens',
#  'eyes',
#  'husbands',
#  'shape',
#  'mind',
#  'look',
#  'unthrift',
#  'world',
#  'doth',
#  'spend',
#  'shifts',
#  'place',
#  'still',
#  'world',
#  'enjoys',
#  'beautys',
#  'waste',
#  'hath',
#  'world',
#  'end',
#  'kept',
#  'unused',
#  'user',
#  'destroys',
#  'love',
#  'toward',
#  'others',
#  'bosom',
#  'sits',
#  'murdrous',
#  'shame',
#  'commits',
#  '10',
#  'shame',
#  'deny',
#  'thou',
#  'bearst',
#  'love',
#  'thy',
#  'self',
#  'art',
#  'unprovident',
#  'grant',
#  'thou',
#  'wilt',
#  'thou',
#  'art',
#  'beloved',
#  'many',
#  'thou',
#  'none',
#  'lovst',
#  'evident',
#  'thou',
#  'art',
#  'possessed',
#  'murdrous',
#  'hate',
#  'gainst',
#  'thy',
#  'self',
#  'thou',
#  'stickst',
#  'conspire',
#  'seeking',
#  'beauteous',
#  'roof',
#  'ruinate',
#  'repair',
#  'thy',
#  'chief',
#  'desire',
#  'change',
#  'thy',
#  'thought',
#  'may',
#  'change',
#  'mind',
#  'shall',
#  'hate',
#  'fairer',
#  'lodged',
#  'gentle',
#  'love',
#  'thy',
#  'presence',
#  'gracious',
#  'kind',
#  'thy',
#  'self',
#  'least',
#  'kindhearted',
#  'prove',
#  'make',
#  'thee',
#  'another',
#  'self',
#  'love',
#  'beauty',
#  'still',
#  'may',
#  'live',
#  'thine',
#  'thee',
#  '11',
#  'fast',
#  'thou',
#  'shalt',
#  'wane',
#  'fast',
#  'thou',
#  'growst',
#  'one',
#  'thine',
#  'thou',
#  'departest',
#  'fresh',
#  'blood',
#  'youngly',
#  'thou',
#  'bestowst',
#  'thou',
#  'mayst',
#  'call',
#  'thine',
#  'thou',
#  'youth',
#  'convertest',
#  'herein',
#  'lives',
#  'wisdom',
#  'beauty',
#  'increase',
#  'without',
#  'folly',
#  'age',
#  'cold',
#  'decay',
#  'minded',
#  'times',
#  'cease',
#  'threescore',
#  'year',
#  'would',
#  'make',
#  'world',
#  'away',
#  'let',
#  'nature',
#  'hath',
#  'made',
#  'store',
#  'harsh',
#  'featureless',
#  'rude',
#  'barrenly',
#  'perish',
#  'look',
#  'best',
#  'endowed',
#  'gave',
#  'thee',
#  'bounteous',
#  'gift',
#  'thou',
#  'shouldst',
#  'bounty',
#  'cherish',
#  'carved',
#  'thee',
#  'seal',
#  'meant',
#  'thereby',
#  'thou',
#  'shouldst',
#  'print',
#  'let',
#  'copy',
#  'die',
#  '12',
#  'count',
#  'clock',
#  'tells',
#  'time',
#  'see',
#  'brave',
#  'day',
#  'sunk',
#  'hideous',
#  'night',
#  'behold',
#  'violet',
#  'past',
#  'prime',
#  'sable',
#  'curls',
#  'silvered',
#  'oer',
#  'white',
#  'lofty',
#  'trees',
#  'see',
#  'barren',
#  'leaves',
#  'erst',
#  'heat',
#  'canopy',
#  'herd',
#  'summers',
#  'green',
#  'girded',
#  'sheaves',
#  'borne',
#  'bier',
#  'white',
#  'bristly',
#  'beard',
#  'thy',
#  'beauty',
#  'question',
#  'make',
#  'thou',
#  'among',
#  'wastes',
#  'time',
#  'must',
#  'go',
#  'since',
#  'sweets',
#  'beauties',
#  'forsake',
#  'die',
#  'fast',
#  'see',
#  'others',
#  'grow',
#  'nothing',
#  'gainst',
#  'times',
#  'scythe',
#  'make',
#  'defence',
#  'save',
#  'breed',
#  'brave',
#  'takes',
#  'thee',
#  'hence',
#  '13',
#  'self',
#  'love',
#  'longer',
#  'self',
#  'live',
#  'coming',
#  'end',
#  'prepare',
#  'sweet',
#  'semblance',
#  'give',
#  'beauty',
#  'hold',
#  'lease',
#  'find',
#  'determination',
#  'self',
#  'selfs',
#  'decease',
#  'sweet',
#  'issue',
#  'sweet',
#  'form',
#  'bear',
#  'lets',
#  'fair',
#  'house',
#  'fall',
#  'decay',
#  'husbandry',
#  'honour',
#  'might',
#  'uphold',
#  'stormy',
#  'gusts',
#  'winters',
#  'day',
#  'barren',
#  'rage',
#  'deaths',
#  'eternal',
#  'cold',
#  'none',
#  'unthrifts',
#  'dear',
#  'love',
#  'know',
#  'father',
#  'let',
#  'son',
#  'say',
#  '14',
#  'stars',
#  'judgement',
#  'pluck',
#  'yet',
#  'methinks',
#  'astronomy',
#  'tell',
#  'good',
#  'evil',
#  'luck',
#  'plagues',
#  'dearths',
#  'seasons',
#  'quality',
#  'fortune',
#  'brief',
#  'minutes',
#  'tell',
#  'pointing',
#  'thunder',
#  'rain',
#  'wind',
#  'say',
#  'princes',
#  'shall',
#  'go',
#  'well',
#  'oft',
#  'predict',
#  'heaven',
#  'find',
#  'thine',
#  'eyes',
#  'knowledge',
#  'derive',
#  'constant',
#  'stars',
#  'read',
#  'art',
#  'truth',
#  'beauty',
#  'shall',
#  'together',
#  'thrive',
#  'thy',
#  'self',
#  'store',
#  'thou',
#  'wouldst',
#  'convert',
#  'else',
#  'thee',
#  'prognosticate',
#  'thy',
#  'end',
#  'truths',
#  'beautys',
#  'doom',
#  'date',
#  '15',
#  'consider',
#  'every',
#  'thing',
#  'grows',
#  'holds',
#  'perfection',
#  'little',
#  'moment',
#  'huge',
#  'stage',
#  'presenteth',
#  'nought',
#  'shows',
#  'whereon',
#  'stars',
#  'secret',
#  'influence',
#  'comment',
#  'perceive',
#  'men',
#  'plants',
#  'increase',
#  'cheered',
#  'checked',
#  'even',
#  'selfsame',
#  'sky',
#  'vaunt',
#  'youthful',
#  'sap',
#  'height',
#  'decrease',
#  'wear',
#  'brave',
#  'state',
#  'memory',
#  'conceit',
#  'inconstant',
#  'stay',
#  'sets',
#  'rich',
#  'youth',
#  'sight',
#  'wasteful',
#  ...]

# %%
print(processed_data[1:15])
print(processed_data[18:32])
# Out:
# ['fairest', 'creatures', 'desire', 'increase', 'thereby', 'beautys', 'rose', 'might', 'never', 'die', 'riper', 'time', 'decease', 'tender']
# ['memory', 'thou', 'contracted', 'thine', 'bright', 'eyes', 'feedst', 'thy', 'lights', 'flame', 'selfsubstantial', 'fuel', 'making', 'famine']
